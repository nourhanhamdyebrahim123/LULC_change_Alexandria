# %% [markdown]
# <a href="https://colab.research.google.com/github/nourhanhamdyebrahim123/LULC_change_Alexandria/blob/main/copy_of_LULC_change_Alex_2045.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install imagecodecs
# Out:
# Requirement already satisfied: imagecodecs in /usr/local/lib/python3.12/dist-packages (2025.8.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from imagecodecs) (2.0.2)

# %%
#!pip install tensorflow==2.13.0
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.19.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pip install segmentation_models generic_utils rasterio
# Out:
# Requirement already satisfied: segmentation_models in /usr/local/lib/python3.12/dist-packages (1.0.1)
# Requirement already satisfied: generic_utils in /usr/local/lib/python3.12/dist-packages (0.20.0)
# Requirement already satisfied: rasterio in /usr/local/lib/python3.12/dist-packages (1.4.3)
# Requirement already satisfied: keras-applications<=1.0.8,>=1.0.7 in /usr/local/lib/python3.12/dist-packages (from segmentation_models) (1.0.8)
# Requirement already satisfied: image-classifiers==1.0.0 in /usr/local/lib/python3.12/dist-packages (from segmentation_models) (1.0.0)
# Requirement already satisfied: efficientnet==1.0.0 in /usr/local/lib/python3.12/dist-packages (from segmentation_models) (1.0.0)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from efficientnet==1.0.0->segmentation_models) (0.25.2)
# Requirement already satisfied: future in /usr/local/lib/python3.12/dist-packages (from generic_utils) (1.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from generic_utils) (75.2.0)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from generic_utils) (1.17.0)
# Requirement already satisfied: affine in /usr/local/lib/python3.12/dist-packages (from rasterio) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from rasterio) (25.4.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from rasterio) (2025.10.5)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.12/dist-packages (from rasterio) (8.3.0)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.12/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.12/dist-packages (from rasterio) (2.0.2)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.12/dist-packages (from rasterio) (1.1.1.2)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from rasterio) (3.2.5)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation_models) (3.15.1)
# Requirement already satisfied: scipy>=1.11.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (1.16.2)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (3.5)
# Requirement already satisfied: pillow>=10.1 in /usr/local/lib/python3.12/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (11.3.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (2025.10.16)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.12/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (25.0)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (0.4)

# %%
import glob
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from keras.callbacks import EarlyStopping

from keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D, BatchNormalization, ConvLSTM2D, Input
from keras.models import Sequential, Model, load_model
import os
import tifffile as tif
from matplotlib import pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from tensorflow.keras.utils import to_categorical
from tensorflow import keras
#import segmentation_models as sm
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import sys
from sklearn.metrics import jaccard_score, f1_score, confusion_matrix, cohen_kappa_score
from datetime import datetime

# %%
data_dir = '/content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2'

# %%
import numpy as np
import os
import glob
import tifffile as tif
import imagecodecs  # Explicit import
import rasterio  # To preserve georeferencing metadata

# Define parameters
total_frames = 288  # Adjust as needed
frames_per_sequence = 4
num_sequences = total_frames // frames_per_sequence
img_height, img_width = 256, 256
array_shape = (num_sequences, frames_per_sequence, img_height, img_width, 1)

x_test = np.zeros(array_shape, dtype=np.float32)

# To store georeference info for each sequence
geo_metadata = []

# Find all X_test image folders
paths = glob.glob(os.path.join(data_dir, '**', 'X_test', 'images'), recursive=True)

seq_idx = 0

for path in sorted(paths):
    masks = [m for m in os.listdir(path) if m.endswith('.tif')]

    # Sort by year extracted from filename (e.g., "image_1995_06.05.tif")
    masks.sort(key=lambda name: int(name.split('_')[1]))

    print(f"\nSequence folder: {path}")
    print(f"Sorted frames: {masks}")

    seq_metadata = []  # Metadata per sequence

    for frame_idx, mask_name in enumerate(masks):
        mask_path = os.path.join(path, mask_name)

        # Use rasterio to read both data and georeference
        with rasterio.open(mask_path) as src:
            mask = src.read(1)  # Read first band
            transform = src.transform
            crs = src.crs
            bounds = src.bounds

        # Handle NaNs and negative values
        mask = np.nan_to_num(mask, nan=1e-6)
        mask[mask <= 0] = 1e-6

        # Expand dims and store
        mask = np.expand_dims(mask, axis=-1)
        x_test[seq_idx, frame_idx] = mask

        # Save metadata for this frame
        seq_metadata.append({
            "filename": mask_name,
            "transform": transform,
            "crs": crs,
            "bounds": bounds
        })

        print(f"  {mask_name} → seq {seq_idx}, frame {frame_idx}")

    geo_metadata.append(seq_metadata)

    seq_idx += 1
    #if seq_idx > num_sequences:
        #break

print("\nFinal array shape_x_test:", x_test.shape)
print(f"Stored georeferenced metadata for {len(geo_metadata)} sequences.")
# Out:
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_01/X_test/images
# Sorted frames: ['image_2005_00.00.tif', 'image_2015_00.00.tif', 'image_2025_00.00.tif', 'image_2035_00.00.tif']
#   image_2005_00.00.tif → seq 0, frame 0
#   image_2015_00.00.tif → seq 0, frame 1
#   image_2025_00.00.tif → seq 0, frame 2
#   image_2035_00.00.tif → seq 0, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_02/X_test/images
# Sorted frames: ['image_2005_00.01.tif', 'image_2015_00.01.tif', 'image_2025_00.01.tif', 'image_2035_00.01.tif']
#   image_2005_00.01.tif → seq 1, frame 0
#   image_2015_00.01.tif → seq 1, frame 1
#   image_2025_00.01.tif → seq 1, frame 2
#   image_2035_00.01.tif → seq 1, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_03/X_test/images
# Sorted frames: ['image_2005_00.02.tif', 'image_2015_00.02.tif', 'image_2025_00.02.tif', 'image_2035_00.02.tif']
#   image_2005_00.02.tif → seq 2, frame 0
#   image_2015_00.02.tif → seq 2, frame 1
#   image_2025_00.02.tif → seq 2, frame 2
#   image_2035_00.02.tif → seq 2, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_04/X_test/images
# Sorted frames: ['image_2005_00.03.tif', 'image_2015_00.03.tif', 'image_2025_00.03.tif', 'image_2035_00.03.tif']
#   image_2005_00.03.tif → seq 3, frame 0
#   image_2015_00.03.tif → seq 3, frame 1
#   image_2025_00.03.tif → seq 3, frame 2
#   image_2035_00.03.tif → seq 3, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_05/X_test/images
# Sorted frames: ['image_2005_00.04.tif', 'image_2015_00.04.tif', 'image_2025_00.04.tif', 'image_2035_00.04.tif']
#   image_2005_00.04.tif → seq 4, frame 0
#   image_2015_00.04.tif → seq 4, frame 1
#   image_2025_00.04.tif → seq 4, frame 2
#   image_2035_00.04.tif → seq 4, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_06/X_test/images
# Sorted frames: ['image_2005_00.05.tif', 'image_2015_00.05.tif', 'image_2025_00.05.tif', 'image_2035_00.05.tif']
#   image_2005_00.05.tif → seq 5, frame 0
#   image_2015_00.05.tif → seq 5, frame 1
#   image_2025_00.05.tif → seq 5, frame 2
#   image_2035_00.05.tif → seq 5, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_07/X_test/images
# Sorted frames: ['image_2005_00.06.tif', 'image_2015_00.06.tif', 'image_2025_00.06.tif', 'image_2035_00.06.tif']
#   image_2005_00.06.tif → seq 6, frame 0
#   image_2015_00.06.tif → seq 6, frame 1
#   image_2025_00.06.tif → seq 6, frame 2
#   image_2035_00.06.tif → seq 6, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_08/X_test/images
# Sorted frames: ['image_2005_00.07.tif', 'image_2015_00.07.tif', 'image_2025_00.07.tif', 'image_2035_00.07.tif']
#   image_2005_00.07.tif → seq 7, frame 0
#   image_2015_00.07.tif → seq 7, frame 1
#   image_2025_00.07.tif → seq 7, frame 2
#   image_2035_00.07.tif → seq 7, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_09/X_test/images
# Sorted frames: ['image_2005_00.08.tif', 'image_2015_00.08.tif', 'image_2025_00.08.tif', 'image_2035_00.08.tif']
#   image_2005_00.08.tif → seq 8, frame 0
#   image_2015_00.08.tif → seq 8, frame 1
#   image_2025_00.08.tif → seq 8, frame 2
#   image_2035_00.08.tif → seq 8, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_10/X_test/images
# Sorted frames: ['image_2005_01.00.tif', 'image_2015_01.00.tif', 'image_2025_01.00.tif', 'image_2035_01.00.tif']
#   image_2005_01.00.tif → seq 9, frame 0
#   image_2015_01.00.tif → seq 9, frame 1
#   image_2025_01.00.tif → seq 9, frame 2
#   image_2035_01.00.tif → seq 9, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_11/X_test/images
# Sorted frames: ['image_2005_01.01.tif', 'image_2015_01.01.tif', 'image_2025_01.01.tif', 'image_2035_01.01.tif']
#   image_2005_01.01.tif → seq 10, frame 0
#   image_2015_01.01.tif → seq 10, frame 1
#   image_2025_01.01.tif → seq 10, frame 2
#   image_2035_01.01.tif → seq 10, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_12/X_test/images
# Sorted frames: ['image_2005_01.02.tif', 'image_2015_01.02.tif', 'image_2025_01.02.tif', 'image_2035_01.02.tif']
#   image_2005_01.02.tif → seq 11, frame 0
#   image_2015_01.02.tif → seq 11, frame 1
#   image_2025_01.02.tif → seq 11, frame 2
#   image_2035_01.02.tif → seq 11, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_13/X_test/images
# Sorted frames: ['image_2005_01.03.tif', 'image_2015_01.03.tif', 'image_2025_01.03.tif', 'image_2035_01.03.tif']
#   image_2005_01.03.tif → seq 12, frame 0
#   image_2015_01.03.tif → seq 12, frame 1
#   image_2025_01.03.tif → seq 12, frame 2
#   image_2035_01.03.tif → seq 12, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_14/X_test/images
# Sorted frames: ['image_2005_01.04.tif', 'image_2015_01.04.tif', 'image_2025_01.04.tif', 'image_2035_01.04.tif']
#   image_2005_01.04.tif → seq 13, frame 0
#   image_2015_01.04.tif → seq 13, frame 1
#   image_2025_01.04.tif → seq 13, frame 2
#   image_2035_01.04.tif → seq 13, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_15/X_test/images
# Sorted frames: ['image_2005_01.05.tif', 'image_2015_01.05.tif', 'image_2025_01.05.tif', 'image_2035_01.05.tif']
#   image_2005_01.05.tif → seq 14, frame 0
#   image_2015_01.05.tif → seq 14, frame 1
#   image_2025_01.05.tif → seq 14, frame 2
#   image_2035_01.05.tif → seq 14, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_16/X_test/images
# Sorted frames: ['image_2005_01.06.tif', 'image_2015_01.06.tif', 'image_2025_01.06.tif', 'image_2035_01.06.tif']
#   image_2005_01.06.tif → seq 15, frame 0
#   image_2015_01.06.tif → seq 15, frame 1
#   image_2025_01.06.tif → seq 15, frame 2
#   image_2035_01.06.tif → seq 15, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_17/X_test/images
# Sorted frames: ['image_2005_01.07.tif', 'image_2015_01.07.tif', 'image_2025_01.07.tif', 'image_2035_01.07.tif']
#   image_2005_01.07.tif → seq 16, frame 0
#   image_2015_01.07.tif → seq 16, frame 1
#   image_2025_01.07.tif → seq 16, frame 2
#   image_2035_01.07.tif → seq 16, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_18/X_test/images
# Sorted frames: ['image_2005_01.08.tif', 'image_2015_01.08.tif', 'image_2025_01.08.tif', 'image_2035_01.08.tif']
#   image_2005_01.08.tif → seq 17, frame 0
#   image_2015_01.08.tif → seq 17, frame 1
#   image_2025_01.08.tif → seq 17, frame 2
#   image_2035_01.08.tif → seq 17, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_19/X_test/images
# Sorted frames: ['image_2005_02.00.tif', 'image_2015_02.00.tif', 'image_2025_02.00.tif', 'image_2035_02.00.tif']
#   image_2005_02.00.tif → seq 18, frame 0
#   image_2015_02.00.tif → seq 18, frame 1
#   image_2025_02.00.tif → seq 18, frame 2
#   image_2035_02.00.tif → seq 18, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_20/X_test/images
# Sorted frames: ['image_2005_02.01.tif', 'image_2015_02.01.tif', 'image_2025_02.01.tif', 'image_2035_02.01.tif']
#   image_2005_02.01.tif → seq 19, frame 0
#   image_2015_02.01.tif → seq 19, frame 1
#   image_2025_02.01.tif → seq 19, frame 2
#   image_2035_02.01.tif → seq 19, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_21/X_test/images
# Sorted frames: ['image_2005_02.02.tif', 'image_2015_02.02.tif', 'image_2025_02.02.tif', 'image_2035_02.02.tif']
#   image_2005_02.02.tif → seq 20, frame 0
#   image_2015_02.02.tif → seq 20, frame 1
#   image_2025_02.02.tif → seq 20, frame 2
#   image_2035_02.02.tif → seq 20, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_22/X_test/images
# Sorted frames: ['image_2005_02.03.tif', 'image_2015_02.03.tif', 'image_2025_02.03.tif', 'image_2035_02.03.tif']
#   image_2005_02.03.tif → seq 21, frame 0
#   image_2015_02.03.tif → seq 21, frame 1
#   image_2025_02.03.tif → seq 21, frame 2
#   image_2035_02.03.tif → seq 21, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_23/X_test/images
# Sorted frames: ['image_2005_02.04.tif', 'image_2015_02.04.tif', 'image_2025_02.04.tif', 'image_2035_02.04.tif']
#   image_2005_02.04.tif → seq 22, frame 0
#   image_2015_02.04.tif → seq 22, frame 1
#   image_2025_02.04.tif → seq 22, frame 2
#   image_2035_02.04.tif → seq 22, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_24/X_test/images
# Sorted frames: ['image_2005_02.05.tif', 'image_2015_02.05.tif', 'image_2025_02.05.tif', 'image_2035_02.05.tif']
#   image_2005_02.05.tif → seq 23, frame 0
#   image_2015_02.05.tif → seq 23, frame 1
#   image_2025_02.05.tif → seq 23, frame 2
#   image_2035_02.05.tif → seq 23, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_25/X_test/images
# Sorted frames: ['image_2005_02.06.tif', 'image_2015_02.06.tif', 'image_2025_02.06.tif', 'image_2035_02.06.tif']
#   image_2005_02.06.tif → seq 24, frame 0
#   image_2015_02.06.tif → seq 24, frame 1
#   image_2025_02.06.tif → seq 24, frame 2
#   image_2035_02.06.tif → seq 24, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_26/X_test/images
# Sorted frames: ['image_2005_02.07.tif', 'image_2015_02.07.tif', 'image_2025_02.07.tif', 'image_2035_02.07.tif']
#   image_2005_02.07.tif → seq 25, frame 0
#   image_2015_02.07.tif → seq 25, frame 1
#   image_2025_02.07.tif → seq 25, frame 2
#   image_2035_02.07.tif → seq 25, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_27/X_test/images
# Sorted frames: ['image_2005_02.08.tif', 'image_2015_02.08.tif', 'image_2025_02.08.tif', 'image_2035_02.08.tif']
#   image_2005_02.08.tif → seq 26, frame 0
#   image_2015_02.08.tif → seq 26, frame 1
#   image_2025_02.08.tif → seq 26, frame 2
#   image_2035_02.08.tif → seq 26, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_28/X_test/images
# Sorted frames: ['image_2005_03.00.tif', 'image_2015_03.00.tif', 'image_2025_03.00.tif', 'image_2035_03.00.tif']
#   image_2005_03.00.tif → seq 27, frame 0
#   image_2015_03.00.tif → seq 27, frame 1
#   image_2025_03.00.tif → seq 27, frame 2
#   image_2035_03.00.tif → seq 27, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_29/X_test/images
# Sorted frames: ['image_2005_03.01.tif', 'image_2015_03.01.tif', 'image_2025_03.01.tif', 'image_2035_03.01.tif']
#   image_2005_03.01.tif → seq 28, frame 0
#   image_2015_03.01.tif → seq 28, frame 1
#   image_2025_03.01.tif → seq 28, frame 2
#   image_2035_03.01.tif → seq 28, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_30/X_test/images
# Sorted frames: ['image_2005_03.02.tif', 'image_2015_03.02.tif', 'image_2025_03.02.tif', 'image_2035_03.02.tif']
#   image_2005_03.02.tif → seq 29, frame 0
#   image_2015_03.02.tif → seq 29, frame 1
#   image_2025_03.02.tif → seq 29, frame 2
#   image_2035_03.02.tif → seq 29, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_31/X_test/images
# Sorted frames: ['image_2005_03.03.tif', 'image_2015_03.03.tif', 'image_2025_03.03.tif', 'image_2035_03.03.tif']
#   image_2005_03.03.tif → seq 30, frame 0
#   image_2015_03.03.tif → seq 30, frame 1
#   image_2025_03.03.tif → seq 30, frame 2
#   image_2035_03.03.tif → seq 30, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_32/X_test/images
# Sorted frames: ['image_2005_03.04.tif', 'image_2015_03.04.tif', 'image_2025_03.04.tif', 'image_2035_03.04.tif']
#   image_2005_03.04.tif → seq 31, frame 0
#   image_2015_03.04.tif → seq 31, frame 1
#   image_2025_03.04.tif → seq 31, frame 2
#   image_2035_03.04.tif → seq 31, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_33/X_test/images
# Sorted frames: ['image_2005_03.05.tif', 'image_2015_03.05.tif', 'image_2025_03.05.tif', 'image_2035_03.05.tif']
#   image_2005_03.05.tif → seq 32, frame 0
#   image_2015_03.05.tif → seq 32, frame 1
#   image_2025_03.05.tif → seq 32, frame 2
#   image_2035_03.05.tif → seq 32, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_34/X_test/images
# Sorted frames: ['image_2005_03.06.tif', 'image_2015_03.06.tif', 'image_2025_03.06.tif', 'image_2035_03.06.tif']
#   image_2005_03.06.tif → seq 33, frame 0
#   image_2015_03.06.tif → seq 33, frame 1
#   image_2025_03.06.tif → seq 33, frame 2
#   image_2035_03.06.tif → seq 33, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_35/X_test/images
# Sorted frames: ['image_2005_03.07.tif', 'image_2015_03.07.tif', 'image_2025_03.07.tif', 'image_2035_03.07.tif']
#   image_2005_03.07.tif → seq 34, frame 0
#   image_2015_03.07.tif → seq 34, frame 1
#   image_2025_03.07.tif → seq 34, frame 2
#   image_2035_03.07.tif → seq 34, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_36/X_test/images
# Sorted frames: ['image_2005_03.08.tif', 'image_2015_03.08.tif', 'image_2025_03.08.tif', 'image_2035_03.08.tif']
#   image_2005_03.08.tif → seq 35, frame 0
#   image_2015_03.08.tif → seq 35, frame 1
#   image_2025_03.08.tif → seq 35, frame 2
#   image_2035_03.08.tif → seq 35, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_37/X_test/images
# Sorted frames: ['image_2005_04.00.tif', 'image_2015_04.00.tif', 'image_2025_04.00.tif', 'image_2035_04.00.tif']
#   image_2005_04.00.tif → seq 36, frame 0
#   image_2015_04.00.tif → seq 36, frame 1
#   image_2025_04.00.tif → seq 36, frame 2
#   image_2035_04.00.tif → seq 36, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_38/X_test/images
# Sorted frames: ['image_2005_04.01.tif', 'image_2015_04.01.tif', 'image_2025_04.01.tif', 'image_2035_04.01.tif']
#   image_2005_04.01.tif → seq 37, frame 0
#   image_2015_04.01.tif → seq 37, frame 1
#   image_2025_04.01.tif → seq 37, frame 2
#   image_2035_04.01.tif → seq 37, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_39/X_test/images
# Sorted frames: ['image_2005_04.02.tif', 'image_2015_04.02.tif', 'image_2025_04.02.tif', 'image_2035_04.02.tif']
#   image_2005_04.02.tif → seq 38, frame 0
#   image_2015_04.02.tif → seq 38, frame 1
#   image_2025_04.02.tif → seq 38, frame 2
#   image_2035_04.02.tif → seq 38, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_40/X_test/images
# Sorted frames: ['image_2005_04.03.tif', 'image_2015_04.03.tif', 'image_2025_04.03.tif', 'image_2035_04.03.tif']
#   image_2005_04.03.tif → seq 39, frame 0
#   image_2015_04.03.tif → seq 39, frame 1
#   image_2025_04.03.tif → seq 39, frame 2
#   image_2035_04.03.tif → seq 39, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_41/X_test/images
# Sorted frames: ['image_2005_04.04.tif', 'image_2015_04.04.tif', 'image_2025_04.04.tif', 'image_2035_04.04.tif']
#   image_2005_04.04.tif → seq 40, frame 0
#   image_2015_04.04.tif → seq 40, frame 1
#   image_2025_04.04.tif → seq 40, frame 2
#   image_2035_04.04.tif → seq 40, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_42/X_test/images
# Sorted frames: ['image_2005_04.05.tif', 'image_2015_04.05.tif', 'image_2025_04.05.tif', 'image_2035_04.05.tif']
#   image_2005_04.05.tif → seq 41, frame 0
#   image_2015_04.05.tif → seq 41, frame 1
#   image_2025_04.05.tif → seq 41, frame 2
#   image_2035_04.05.tif → seq 41, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_43/X_test/images
# Sorted frames: ['image_2005_04.06.tif', 'image_2015_04.06.tif', 'image_2025_04.06.tif', 'image_2035_04.06.tif']
#   image_2005_04.06.tif → seq 42, frame 0
#   image_2015_04.06.tif → seq 42, frame 1
#   image_2025_04.06.tif → seq 42, frame 2
#   image_2035_04.06.tif → seq 42, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_44/X_test/images
# Sorted frames: ['image_2005_04.07.tif', 'image_2015_04.07.tif', 'image_2025_04.07.tif', 'image_2035_04.07.tif']
#   image_2005_04.07.tif → seq 43, frame 0
#   image_2015_04.07.tif → seq 43, frame 1
#   image_2025_04.07.tif → seq 43, frame 2
#   image_2035_04.07.tif → seq 43, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_45/X_test/images
# Sorted frames: ['image_2005_04.08.tif', 'image_2015_04.08.tif', 'image_2025_04.08.tif', 'image_2035_04.08.tif']
#   image_2005_04.08.tif → seq 44, frame 0
#   image_2015_04.08.tif → seq 44, frame 1
#   image_2025_04.08.tif → seq 44, frame 2
#   image_2035_04.08.tif → seq 44, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_46/X_test/images
# Sorted frames: ['image_2005_05.00.tif', 'image_2015_05.00.tif', 'image_2025_05.00.tif', 'image_2035_05.00.tif']
#   image_2005_05.00.tif → seq 45, frame 0
#   image_2015_05.00.tif → seq 45, frame 1
#   image_2025_05.00.tif → seq 45, frame 2
#   image_2035_05.00.tif → seq 45, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_47/X_test/images
# Sorted frames: ['image_2005_05.01.tif', 'image_2015_05.01.tif', 'image_2025_05.01.tif', 'image_2035_05.01.tif']
#   image_2005_05.01.tif → seq 46, frame 0
#   image_2015_05.01.tif → seq 46, frame 1
#   image_2025_05.01.tif → seq 46, frame 2
#   image_2035_05.01.tif → seq 46, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_48/X_test/images
# Sorted frames: ['image_2005_05.02.tif', 'image_2015_05.02.tif', 'image_2025_05.02.tif', 'image_2035_05.02.tif']
#   image_2005_05.02.tif → seq 47, frame 0
#   image_2015_05.02.tif → seq 47, frame 1
#   image_2025_05.02.tif → seq 47, frame 2
#   image_2035_05.02.tif → seq 47, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_49/X_test/images
# Sorted frames: ['image_2005_05.03.tif', 'image_2015_05.03.tif', 'image_2025_05.03.tif', 'image_2035_05.03.tif']
#   image_2005_05.03.tif → seq 48, frame 0
#   image_2015_05.03.tif → seq 48, frame 1
#   image_2025_05.03.tif → seq 48, frame 2
#   image_2035_05.03.tif → seq 48, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_50/X_test/images
# Sorted frames: ['image_2005_05.04.tif', 'image_2015_05.04.tif', 'image_2025_05.04.tif', 'image_2035_05.04.tif']
#   image_2005_05.04.tif → seq 49, frame 0
#   image_2015_05.04.tif → seq 49, frame 1
#   image_2025_05.04.tif → seq 49, frame 2
#   image_2035_05.04.tif → seq 49, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_51/X_test/images
# Sorted frames: ['image_2005_05.05.tif', 'image_2015_05.05.tif', 'image_2025_05.05.tif', 'image_2035_05.05.tif']
#   image_2005_05.05.tif → seq 50, frame 0
#   image_2015_05.05.tif → seq 50, frame 1
#   image_2025_05.05.tif → seq 50, frame 2
#   image_2035_05.05.tif → seq 50, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_52/X_test/images
# Sorted frames: ['image_2005_05.06.tif', 'image_2015_05.06.tif', 'image_2025_05.06.tif', 'image_2035_05.06.tif']
#   image_2005_05.06.tif → seq 51, frame 0
#   image_2015_05.06.tif → seq 51, frame 1
#   image_2025_05.06.tif → seq 51, frame 2
#   image_2035_05.06.tif → seq 51, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_53/X_test/images
# Sorted frames: ['image_2005_05.07.tif', 'image_2015_05.07.tif', 'image_2025_05.07.tif', 'image_2035_05.07.tif']
#   image_2005_05.07.tif → seq 52, frame 0
#   image_2015_05.07.tif → seq 52, frame 1
#   image_2025_05.07.tif → seq 52, frame 2
#   image_2035_05.07.tif → seq 52, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_54/X_test/images
# Sorted frames: ['image_2005_05.08.tif', 'image_2015_05.08.tif', 'image_2025_05.08.tif', 'image_2035_05.08.tif']
#   image_2005_05.08.tif → seq 53, frame 0
#   image_2015_05.08.tif → seq 53, frame 1
#   image_2025_05.08.tif → seq 53, frame 2
#   image_2035_05.08.tif → seq 53, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_55/X_test/images
# Sorted frames: ['image_2005_06.00.tif', 'image_2015_06.00.tif', 'image_2025_06.00.tif', 'image_2035_06.00.tif']
#   image_2005_06.00.tif → seq 54, frame 0
#   image_2015_06.00.tif → seq 54, frame 1
#   image_2025_06.00.tif → seq 54, frame 2
#   image_2035_06.00.tif → seq 54, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_56/X_test/images
# Sorted frames: ['image_2005_06.01.tif', 'image_2015_06.01.tif', 'image_2025_06.01.tif', 'image_2035_06.01.tif']
#   image_2005_06.01.tif → seq 55, frame 0
#   image_2015_06.01.tif → seq 55, frame 1
#   image_2025_06.01.tif → seq 55, frame 2
#   image_2035_06.01.tif → seq 55, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_57/X_test/images
# Sorted frames: ['image_2005_06.02.tif', 'image_2015_06.02.tif', 'image_2025_06.02.tif', 'image_2035_06.02.tif']
#   image_2005_06.02.tif → seq 56, frame 0
#   image_2015_06.02.tif → seq 56, frame 1
#   image_2025_06.02.tif → seq 56, frame 2
#   image_2035_06.02.tif → seq 56, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_58/X_test/images
# Sorted frames: ['image_2005_06.03.tif', 'image_2015_06.03.tif', 'image_2025_06.03.tif', 'image_2035_06.03.tif']
#   image_2005_06.03.tif → seq 57, frame 0
#   image_2015_06.03.tif → seq 57, frame 1
#   image_2025_06.03.tif → seq 57, frame 2
#   image_2035_06.03.tif → seq 57, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_59/X_test/images
# Sorted frames: ['image_2005_06.04.tif', 'image_2015_06.04.tif', 'image_2025_06.04.tif', 'image_2035_06.04.tif']
#   image_2005_06.04.tif → seq 58, frame 0
#   image_2015_06.04.tif → seq 58, frame 1
#   image_2025_06.04.tif → seq 58, frame 2
#   image_2035_06.04.tif → seq 58, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_60/X_test/images
# Sorted frames: ['image_2005_06.05.tif', 'image_2015_06.05.tif', 'image_2025_06.05.tif', 'image_2035_06.05.tif']
#   image_2005_06.05.tif → seq 59, frame 0
#   image_2015_06.05.tif → seq 59, frame 1
#   image_2025_06.05.tif → seq 59, frame 2
#   image_2035_06.05.tif → seq 59, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_61/X_test/images
# Sorted frames: ['image_2005_06.06.tif', 'image_2015_06.06.tif', 'image_2025_06.06.tif', 'image_2035_06.06.tif']
#   image_2005_06.06.tif → seq 60, frame 0
#   image_2015_06.06.tif → seq 60, frame 1
#   image_2025_06.06.tif → seq 60, frame 2
#   image_2035_06.06.tif → seq 60, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_62/X_test/images
# Sorted frames: ['image_2005_06.07.tif', 'image_2015_06.07.tif', 'image_2025_06.07.tif', 'image_2035_06.07.tif']
#   image_2005_06.07.tif → seq 61, frame 0
#   image_2015_06.07.tif → seq 61, frame 1
#   image_2025_06.07.tif → seq 61, frame 2
#   image_2035_06.07.tif → seq 61, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_63/X_test/images
# Sorted frames: ['image_2005_06.08.tif', 'image_2015_06.08.tif', 'image_2025_06.08.tif', 'image_2035_06.08.tif']
#   image_2005_06.08.tif → seq 62, frame 0
#   image_2015_06.08.tif → seq 62, frame 1
#   image_2025_06.08.tif → seq 62, frame 2
#   image_2035_06.08.tif → seq 62, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_64/X_test/images
# Sorted frames: ['image_2005_07.00.tif', 'image_2015_07.00.tif', 'image_2025_07.00.tif', 'image_2035_07.00.tif']
#   image_2005_07.00.tif → seq 63, frame 0
#   image_2015_07.00.tif → seq 63, frame 1
#   image_2025_07.00.tif → seq 63, frame 2
#   image_2035_07.00.tif → seq 63, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_65/X_test/images
# Sorted frames: ['image_2005_07.01.tif', 'image_2015_07.01.tif', 'image_2025_07.01.tif', 'image_2035_07.01.tif']
#   image_2005_07.01.tif → seq 64, frame 0
#   image_2015_07.01.tif → seq 64, frame 1
#   image_2025_07.01.tif → seq 64, frame 2
#   image_2035_07.01.tif → seq 64, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_66/X_test/images
# Sorted frames: ['image_2005_07.02.tif', 'image_2015_07.02.tif', 'image_2025_07.02.tif', 'image_2035_07.02.tif']
#   image_2005_07.02.tif → seq 65, frame 0
#   image_2015_07.02.tif → seq 65, frame 1
#   image_2025_07.02.tif → seq 65, frame 2
#   image_2035_07.02.tif → seq 65, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_67/X_test/images
# Sorted frames: ['image_2005_07.03.tif', 'image_2015_07.03.tif', 'image_2025_07.03.tif', 'image_2035_07.03.tif']
#   image_2005_07.03.tif → seq 66, frame 0
#   image_2015_07.03.tif → seq 66, frame 1
#   image_2025_07.03.tif → seq 66, frame 2
#   image_2035_07.03.tif → seq 66, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_68/X_test/images
# Sorted frames: ['image_2005_07.04.tif', 'image_2015_07.04.tif', 'image_2025_07.04.tif', 'image_2035_07.04.tif']
#   image_2005_07.04.tif → seq 67, frame 0
#   image_2015_07.04.tif → seq 67, frame 1
#   image_2025_07.04.tif → seq 67, frame 2
#   image_2035_07.04.tif → seq 67, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_69/X_test/images
# Sorted frames: ['image_2005_07.05.tif', 'image_2015_07.05.tif', 'image_2025_07.05.tif', 'image_2035_07.05.tif']
#   image_2005_07.05.tif → seq 68, frame 0
#   image_2015_07.05.tif → seq 68, frame 1
#   image_2025_07.05.tif → seq 68, frame 2
#   image_2035_07.05.tif → seq 68, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_70/X_test/images
# Sorted frames: ['image_2005_07.06.tif', 'image_2015_07.06.tif', 'image_2025_07.06.tif', 'image_2035_07.06.tif']
#   image_2005_07.06.tif → seq 69, frame 0
#   image_2015_07.06.tif → seq 69, frame 1
#   image_2025_07.06.tif → seq 69, frame 2
#   image_2035_07.06.tif → seq 69, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_71/X_test/images
# Sorted frames: ['image_2005_07.07.tif', 'image_2015_07.07.tif', 'image_2025_07.07.tif', 'image_2035_07.07.tif']
#   image_2005_07.07.tif → seq 70, frame 0
#   image_2015_07.07.tif → seq 70, frame 1
#   image_2025_07.07.tif → seq 70, frame 2
#   image_2035_07.07.tif → seq 70, frame 3
#
# Sequence folder: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2/Sequence_72/X_test/images
# Sorted frames: ['image_2005_07.08.tif', 'image_2015_07.08.tif', 'image_2025_07.08.tif', 'image_2035_07.08.tif']
#   image_2005_07.08.tif → seq 71, frame 0
#   image_2015_07.08.tif → seq 71, frame 1
#   image_2025_07.08.tif → seq 71, frame 2
#   image_2035_07.08.tif → seq 71, frame 3
#
# Final array shape_x_test: (72, 4, 256, 256, 1)
# Stored georeferenced metadata for 72 sequences.

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, ConvLSTM2D, BatchNormalization, Dense
# import segmentation_models as sm # Removed this import as it's causing the error

# Define your custom loss and metrics again (same as in training)
# If you don't have them right now, use dummy ones temporarily.
def total_loss(y_true, y_pred):
    return tf.reduce_mean(tf.square(y_true - y_pred))  # Example: MSE

# Re-defining metrics without relying on segmentation_models
# Assuming these were the metrics used during training
def iou_score(y_true, y_pred, threshold=0.5):
    y_pred = tf.cast(y_pred > threshold, tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) - intersection
    return intersection / (union + tf.keras.backend.epsilon())

def f1_score(y_true, y_pred, threshold=0.5):
    y_pred = tf.cast(y_pred > threshold, tf.float32)
    tp = tf.reduce_sum(y_true * y_pred)
    fp = tf.reduce_sum((1 - y_true) * y_pred)
    fn = tf.reduce_sum(y_true * (1 - y_pred))
    precision = tp / (tp + fp + tf.keras.backend.epsilon())
    recall = tp / (tp + fn + tf.keras.backend.epsilon())
    return 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())

metrics = [iou_score, f1_score]


def build_convlstm_model():
    image_input = Input(shape=(4, 256, 256, 1))

    x = ConvLSTM2D(filters=64, kernel_size=(3, 3), padding='same', return_sequences=True)(image_input)
    x = BatchNormalization()(x)
    x = ConvLSTM2D(filters=32, kernel_size=(3, 3), padding='same', return_sequences=False)(x)
    x = BatchNormalization()(x)

    # The output layer should match the number of classes in your segmentation task.
    # Based on the later use of np.argmax with axis=3, it seems you have 4 classes.
    x = Dense(4, activation='softmax')(x)

    model = Model(inputs=image_input, outputs=x)
    # Compile the model with the same optimizer and loss function used during training
    model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=metrics)
    return model

# ---- Build and load weights ----
model = build_convlstm_model()

# Load weights (not the full model, to avoid version mismatch issues)
model.load_weights("/content/drive/My Drive/LULC_change_modeling_Alex/convlstm_time_series.hdf5")

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 4, 256, 256, 1) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_lstm2d (ConvLSTM2D)        │ (None, 4, 256, 256,    │       150,016 │
# │                                 │ 64)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 4, 256, 256,    │           256 │
# │ (BatchNormalization)            │ 64)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_lstm2d_1 (ConvLSTM2D)      │ (None, 256, 256, 32)   │       110,720 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 256, 256, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256, 256, 4)    │           132 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 261,252 (1020.52 KB)
#  Trainable params: 261,060 (1019.77 KB)
#  Non-trainable params: 192 (768.00 B)

# %%
from google.colab import drive
import os

# Mount Drive (safe re-mount if already mounted)
drive.mount('/content/drive', force_remount=True)

# ✅ Define the correct path — note the r'' raw string to handle spaces
data_dir = r'/content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2045'

# ✅ Check if the directory exists
if not os.path.exists(data_dir):
    print(f"❌ Directory not found: {data_dir}")
    print("\n🔍 Let's list available folders under 'My Drive/LULC_change_modeling_Alex':\n")
    base_path = '/content/drive/My Drive/LULC_change_modeling_Alex'
    if os.path.exists(base_path):
        for item in os.listdir(base_path):
            print("📁", item)
    else:
        print("⚠️ 'LULC_change_modeling_Alex' folder not found. Check your Drive mount.")
else:
    print(f"✅ Found directory: {data_dir}\n")
    print("📂 Folder structure under data_dir:\n")
    for root, dirs, files in os.walk(data_dir):
        level = root.replace(data_dir, '').count(os.sep)
        indent = ' ' * 2 * level
        print(f"{indent}{os.path.basename(root)}/")
        if level >= 3:
            continue
# Out:
# Mounted at /content/drive
# ❌ Directory not found: /content/drive/My Drive/LULC_change_modeling_Alex/Dataset_2045
#
# 🔍 Let's list available folders under 'My Drive/LULC_change_modeling_Alex':
#
# 📁 convlstm_time_series.hdf5
# 📁 Dataset_2
# 📁 Results_2035
# 📁 Dataset_2035

# %%
predicted_image = model.predict(x_test)
predicted_image = np.argmax(predicted_image, axis=3).astype(np.uint32)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 14s 3s/step

# %%
import os
import rasterio
import numpy as np

# === Define the output directory ===
output_directory = "/content/drive/My Drive/LULC_change_modeling_Alex/Results_2"
os.makedirs(output_directory, exist_ok=True)

# === Loop through predicted patches ===
for k in range(len(predicted_image)):
    print("shape of predicted_image[k]:", predicted_image[k].shape)

    # Get the metadata for the current sequence (k) and the last frame (index 3)
    # assuming the prediction corresponds to the last frame of the sequence
    if k < len(geo_metadata) and len(geo_metadata[k]) > 0:
        reference_metadata = geo_metadata[k][-1] # Get metadata for the last frame
        reference_path = os.path.join(data_dir, 'Sequence_{:02d}'.format(k+1), 'X_test', 'images', reference_metadata['filename'])
    else:
        print(f"Warning: Could not find metadata for sequence {k}. Skipping.")
        continue


    # --- Load georeferencing from the corresponding input patch ---
    try:
        with rasterio.open(reference_path) as src:
            meta = src.meta.copy()
            transform = src.transform
            crs = src.crs
    except Exception as e:
        print(f"Error opening reference file {reference_path}: {e}")
        continue


    # --- Update metadata for predicted output ---
    meta.update({
        "count": 1,
        "dtype": rasterio.uint32,
        "transform": transform,
        "crs": crs
    })

    # --- Construct the full output path ---
    img_name = f"prediction_{k:02}"
    output_geotiff_path = os.path.join(output_directory, img_name + ".tif")

    # --- Save predicted patch with georeferencing ---
    with rasterio.open(output_geotiff_path, "w", **meta) as dst:
        dst.write(predicted_image[k], 1)

    print(f"✅ Saved georeferenced prediction to: {output_geotiff_path}")
# Out:
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_00.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_01.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_02.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_03.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_04.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_05.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_06.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_07.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_08.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_09.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_10.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_11.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_12.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_13.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_14.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_15.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_16.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_17.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_18.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_19.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_20.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_21.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_22.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_23.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_24.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_25.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_26.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_27.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_28.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_29.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_30.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_31.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_32.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_33.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_34.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_35.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_36.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_37.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_38.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_39.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_40.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_41.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_42.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_43.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_44.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_45.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_46.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_47.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_48.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_49.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_50.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_51.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_52.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_53.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_54.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_55.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_56.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_57.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_58.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_59.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_60.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_61.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_62.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_63.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_64.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_65.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_66.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_67.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_68.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_69.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_70.tif
# shape of predicted_image[k]: (256, 256)
# ✅ Saved georeferenced prediction to: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/prediction_71.tif

# %%
from rasterio.merge import merge
import glob

# Collect all patch GeoTIFFs
# Correct the glob pattern to match the saved filenames
tif_files = sorted(glob.glob(os.path.join(output_directory, "prediction_*.tif")))

# Merge patches into one full raster
src_files_to_mosaic = [rasterio.open(fp) for fp in tif_files]
mosaic, out_transform = merge(src_files_to_mosaic)

# Update metadata
# Assuming 'meta' variable from previous cell is still available and relevant
# If not, you might need to open one of the source files to get initial metadata
if 'meta' not in locals():
    with rasterio.open(tif_files[0]) as src:
        meta = src.meta.copy()


meta.update({
    "height": mosaic.shape[1],
    "width": mosaic.shape[2],
    "transform": out_transform
})

# Save final merged GeoTIFF
merged_path = os.path.join(output_directory, "predicted_full_lulc_2045.tif")
with rasterio.open(merged_path, "w", **meta) as dst:
    dst.write(mosaic)

print("✅ Merged georeferenced full prediction saved:", merged_path)
# Out:
# ✅ Merged georeferenced full prediction saved: /content/drive/My Drive/LULC_change_modeling_Alex/Results_2/predicted_full_lulc_2045.tif
